# %%
import requests
from IPython.display import Image, display

print("======================================")
print("       RANDOM DOG IMAGE GENERATOR")
print("======================================")

# API URL
url = "https://dog.ceo/api/breeds/image/random"

# Send request to API
response = requests.get(url)

if response.status_code == 200:

    data = response.json()

    image_url = data["message"]

    print("\nRandom dog image generated successfully!")
    print("Image URL:", image_url)

    # Display image in Google Colab
    display(Image(url=image_url))

else:

    print("Unable to connect to the Dog API.")

print("\n======================================")
# Out:
# ======================================
#        RANDOM DOG IMAGE GENERATOR
# ======================================
#
# Random dog image generated successfully!
# Image URL: https://images.dog.ceo/breeds/terrier-westhighland/n02098286_4176.jpg
# <img src="https://images.dog.ceo/breeds/terrier-westhighland/n02098286_4176.jpg"/>
# ======================================
